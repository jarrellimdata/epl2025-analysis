# %% [markdown]
# # Answering Business Questions

# %% [markdown]
# Q1: Which referees officiate the most matches, and do they call more fouls and issue more cards than others?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Answer:
# - Among the top referees, M Oliver calls the most fouls and issues the most cards on average.
# - A Taylor, despite officiating the most matches, calls fewer fouls and cards.

# %% [markdown]
# Q2. What predicts a high-scoring match? Which match statistics best differentiate high-scoring matches from low-scoring ones?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Given that average goals per match for this season is 2.93, I set a high scoring benchmark at 3 or more goals.
# - Using this benchmark, the following analysis compares high scoring matches (3+ goals) against low scoring matches (below 3 goals) based on shots, corners, and yellow cards.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Answer:
# - High-scoring matches have more shots on goal (26.9 vs. 24.6), while corners and yellow cards show minimal difference. Shots are the strongest indicator of a high-scoring game.

# %% [markdown]
# Q3. What role do corners and shots play in determining match results?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Answer:
# Home wins are associated with more shots taken by the home team (15 vs. 10 by away teams), suggesting that outshooting the opponent increases chances of victory. Draws show balanced shot counts, while away wins often involve the away team taking more shots. Corners are relatively even across outcomes, indicating they may play a smaller role.

# %% [markdown]
# Q4. How do cards impact match outcomes?

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Answer:
# - Drawn matches have the highest average yellow cards for both home (2.08) and away (2.38) teams.
# - Home wins show slightly fewer yellow cards for home teams (1.79) but more for away teams (2.16).
# - Red cards remain low across all outcomes.
# - This suggests matches with more yellow cards tend to be more contested and often end in draws.

# %% [markdown]
# Q5: Which teams have the highest shot accuracy, and how does it relate to their overall win rate?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Answer:
# - Brentford had the highest shot accuracy (41.7%) but only a 42.1% win rate, while Liverpool (35.6% accuracy) and Man City (35.7%) had much higher win rates at 65.8% and 55.3%. This suggests that while shot accuracy matters, factors like chance quality, tactics, and defense play a bigger role in winning matches.

# %% [markdown]
# Q6: Shot Accuracy vs. Match Outcome (including draws)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In home wins, the home team is more accurate with 41% compared to 32% for the away team. In away wins, away teams have higher accuracy at 42% while the home team has 32%. Draws show similar accuracy for both sides, around 34% and 35%. This suggests shot accuracy is a strong indicator of match outcome, with the more accurate team usually winning.

# %% [markdown]
# Q7: Top 10 Highest Scoring Matches

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q8: Relationship between second_half_impact and match outcomes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Answer (Summary):
# - Matches with strong positive second half impact (3 and 4) make up just under 4% of games but have a 100% home win rate.
# - Most games fall between impacts of -1 and 1, covering about 73% of matches, with home wins decreasing and away wins increasing as impact shifts negative.
# - Negative impacts (-2 to -4) show very high away win rates, close to 90-100%, but these matches are less common (around 14% total).
# - Draws remain at 0% across all impact levels in this output.
